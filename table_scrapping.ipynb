# %%
import requests 
from bs4 import BeautifulSoup
import os

# %% [markdown]
# Scraping the table from website using BeautifulSoup and creating a csv file.

# %%
url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(url,'lxml')
my_table = soup.find('table',{'class':'wikitable sortable'})
rows = my_table.findAll('tr')
table_content = ""
for table_rows in my_table.findAll("tr"):
    data = ""
    for table_data in my_table.findAll("td"):
        data = data + "," + table_data.text
    if len(data)!=0:
        table_content = table_content  + data[0:]

header = "Postalcode,Borough,Neighbourhood" + "\n"
file = open(os.path.expanduser("table.csv"),"wb")
file.write(bytes(header, encoding = "ascii", errors = "ignore"))
file.write(bytes(table_content, encoding = "ascii", errors = "ignore"))
# Out:
# 2627980

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing table.csv file into pandas dataframe

# %%
toronto_df = pd.read_csv('table.csv')

# %%
toronto_df = toronto_df[toronto_df.Borough != 'NaN']

# %% [markdown]
# Add numeric index.

# %%
toronto_df.index = pd.RangeIndex(len(toronto_df.index))
toronto_df.head()
# Out:
#   Postalcode           Borough     Neighbourhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# Remove the rows with Borough == Not assigned

# %%
toronto_df["Borough"] = toronto_df["Borough"].replace(["Not assigned"], np.nan)

# %%
toronto_df = toronto_df.dropna(subset = ["Borough"])

# %%
toronto_df.head()
# Out:
#   Postalcode           Borough     Neighbourhood
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront
# 5        M5A  Downtown Toronto       Regent Park
# 6        M6A        North York  Lawrence Heights

# %% [markdown]
# Required Dataframe.

# %%
new_df=toronto_df.groupby("Postalcode").agg(lambda x:','.join(set(x)))
new_df.loc[new_df['Neighbourhood']=="Not assigned",'Neighbourhood']=new_df.loc[new_df['Neighbourhood']=="Not assigned",'Borough']
new_df
# Out:
#                      Borough  \
# Postalcode
# M1B              Scarborough
# M1C              Scarborough
# M1E              Scarborough
# M1G              Scarborough
# M1H              Scarborough
# M1J              Scarborough
# M1K              Scarborough
# M1L              Scarborough
# M1M              Scarborough
# M1N              Scarborough
# M1P              Scarborough
# M1R              Scarborough
# M1S              Scarborough
# M1T              Scarborough
# M1V              Scarborough
# M1W              Scarborough
# M1X              Scarborough
# M2H               North York
# M2J               North York
# M2K               North York
# M2L               North York
# M2M               North York
# M2N               North York
# M2P               North York
# M2R               North York
# M3A               North York
# M3B               North York
# M3C               North York
# M3H               North York
# M3J               North York
# ...                      ...
# M6C                     York
# M6E                     York
# M6G         Downtown Toronto
# M6H             West Toronto
# M6J             West Toronto
# M6K             West Toronto
# M6L               North York
# M6M                     York
# M6N                     York
# M6P             West Toronto
# M6R             West Toronto
# M6S             West Toronto
# M7A             Queen's Park
# M7R              Mississauga
# M7Y             East Toronto
# M8V                Etobicoke
# M8W                Etobicoke
# M8X                Etobicoke
# M8Y                Etobicoke
# M8Z                Etobicoke
# M9A                Etobicoke
# M9B                Etobicoke
# M9C                Etobicoke
# M9L               North York
# M9M               North York
# M9N                     York
# M9P                Etobicoke
# M9R                Etobicoke
# M9V                Etobicoke
# M9W                Etobicoke
#
#                                                 Neighbourhood
# Postalcode
# M1B                                             Malvern,Rouge
# M1C                      Highland Creek,Rouge Hill,Port Union
# M1E                           Morningside,Guildwood,West Hill
# M1G                                                    Woburn
# M1H                                                 Cedarbrae
# M1J                                       Scarborough Village
# M1K                 Ionview,Kennedy Park,East Birchmount Park
# M1L                             Golden Mile,Clairlea,Oakridge
# M1M             Cliffside,Scarborough Village West,Cliffcrest
# M1N                                Cliffside West,Birch Cliff
# M1P         Scarborough Town Centre,Wexford Heights,Dorset...
# M1R                                          Wexford,Maryvale
# M1S                                                 Agincourt
# M1T                     Sullivan,Clarks Corners,Tam O'Shanter
# M1V         Agincourt North,Steeles East,L'Amoreaux East,M...
# M1W                              L'Amoreaux West,Steeles West
# M1X                                               Upper Rouge
# M2H                                         Hillcrest Village
# M2J                                Fairview,Oriole,Henry Farm
# M2K                                           Bayview Village
# M2L                                   Silver Hills,York Mills
# M2M                                    Willowdale,Newtonbrook
# M2N                                          Willowdale South
# M2P                                           York Mills West
# M2R                                           Willowdale West
# M3A                                                 Parkwoods
# M3B                                           Don Mills North
# M3C                           Don Mills South,Flemingdon Park
# M3H             Downsview North,Wilson Heights,Bathurst Manor
# M3J                            Northwood Park,York University
# ...                                                       ...
# M6C                                        Humewood-Cedarvale
# M6E                                       Caledonia-Fairbanks
# M6G                                                  Christie
# M6H                               Dovercourt Village,Dufferin
# M6J                                   Little Portugal,Trinity
# M6K                Exhibition Place,Parkdale Village,Brockton
# M6L                    Upwood Park,North Park,Maple Leaf Park
# M6M               Silverthorn,Mount Dennis,Keelesdale,Del Ray
# M6N                              The Junction North,Runnymede
# M6P                              High Park,The Junction South
# M6R                                     Parkdale,Roncesvalles
# M6S                                         Swansea,Runnymede
# M7A                                              Queen's Park
# M7R                     Canada Post Gateway Processing Centre
# M7Y         Business Reply Mail Processing Centre 969 Eastern
# M8V                Mimico South,New Toronto,Humber Bay Shores
# M8W                                     Alderwood,Long Branch
# M8X               The Kingsway,Montgomery Road,Old Mill North
# M8Y         Sunnylea,Kingsway Park South East,Mimico NE,Th...
# M8Z         Kingsway Park South West,The Queensway West,Mi...
# M9A                                          Islington Avenue
# M9B         Princess Gardens,West Deane Park,Martin Grove,...
# M9C         Markland Wood,Old Burnhamthorpe,Bloordale Gard...
# M9L                                             Humber Summit
# M9M                                           Emery,Humberlea
# M9N                                                    Weston
# M9P                                                 Westmount
# M9R         Richview Gardens,Kingsview Village,St. Phillip...
# M9V         Mount Olive,South Steeles,Thistletown,Silverst...
# M9W                                                 Northwest
#
# [103 rows x 2 columns]

# %%
new_df.shape
# Out:
# (103, 2)
